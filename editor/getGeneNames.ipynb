# %%
import pandas as pd

# %%
ds = pd.read_csv('../data/protein_quant_14853.tsv', delimiter='\t')

# %%
ds
# Out:
#                        Protein Id Gene Symbol  \
# 0            sp|Q9BRJ7|SDOS_HUMAN    NUDT16L1
# 1          sp|Q8TC05-2|MDM1_HUMAN        MDM1
# 2       ##sp|P14373-2|TRI27_HUMAN      TRIM27
# 3           sp|Q9Y6X5|ENPP4_HUMAN       ENPP4
# 4           sp|O60218|AK1BA_HUMAN     AKR1B10
# 5            sp|O95810|SDPR_HUMAN        SDPR
# 6           sp|P42330|AK1C3_HUMAN      AKR1C3
# 7         sp|A2RUB1-1|CQ104_HUMAN   C17orf104
# 8           sp|P05362|ICAM1_HUMAN       ICAM1
# 9           sp|P02686-2|MBP_HUMAN         MBP
# 10         sp|O75781-2|PALM_HUMAN        PALM
# 11          sp|P02511|CRYAB_HUMAN       CRYAB
# 12          sp|P02533|K1C14_HUMAN       KRT14
# 13           sp|P48681|NEST_HUMAN         NES
# 14        sp|Q15052-2|ARHG6_HUMAN     ARHGEF6
# 15      ##sp|Q7Z422-3|CA144_HUMAN    C1orf144
# 16          sp|P21266|GSTM3_HUMAN       GSTM3
# 17          sp|O94761|RECQ4_HUMAN      RECQL4
# 18          sp|Q9UHF1|EGFL7_HUMAN       EGFL7
# ...

# %%
toMod = ds['Gene Symbol']
toMod
# Out:
# 0        NUDT16L1
# 1            MDM1
# 2          TRIM27
# 3           ENPP4
# 4         AKR1B10
# 5            SDPR
# 6          AKR1C3
# 7       C17orf104
# 8           ICAM1
# 9             MBP
# 10           PALM
# 11          CRYAB
# 12          KRT14
# 13            NES
# 14        ARHGEF6
# 15       C1orf144
# 16          GSTM3
# 17         RECQL4
# 18          EGFL7
# 19         ZNF185
# 20           CTSZ
# 21         CLEC3B
# 22        APBB1IP
# 23           PFN2
# 24           KAZN
# 25           MSMP
# 26           KRT9
# 27            NaN
# 28           CNN1
# 29        TRIP6i2
#           ...
# 8159       GPRC5A
# 8160       FIP1L1
# 8161       CLSTN3
# 8162     KIAA1199
# 8163        TIMP3
# 8164       TMEM35
# 8165        GAP43
# 8166         HHIP
# 8167       HIRIP3
# 8168      PSTPIP2
# 8169         GPC6
# 8170        CWC15
# 8171       ARMCX2
# 8172         IL1B
# 8173        VPS72
# 8174       CLASRP
# 8175          CA9
# 8176     TMEM200A
# 8177        SRSF1
# ...
